# %%
import pandas as pd

# %%
train_df = pd.read_csv("C:\\Users\\akshatha\\Downloads\\archive (5)\\test.txt", sep = ';', names = ['text', 'Emotion'])
print(train_df.head())
# Out:
#                                                 text  Emotion
# 0  im feeling rather rotten so im not very ambiti...  sadness
# 1          im updating my blog because i feel shitty  sadness
# 2  i never make her separate from me because i do...  sadness
# 3  i left with my bouquet of red and yellow tulip...      joy
# 4    i was feeling a little vain when i did this one  sadness

# %%
val_df = pd.read_csv("C:\\Users\\akshatha\\Downloads\\archive (5)\\val.txt", sep = ';', names = ['text', 'Emotion'])
print(val_df.head())
# Out:
#                                                 text  Emotion
# 0  im feeling quite sad and sorry for myself but ...  sadness
# 1  i feel like i am still looking at a blank canv...  sadness
# 2                     i feel like a faithful servant     love
# 3                  i am just feeling cranky and blue    anger
# 4  i can have for a treat or if i am feeling festive      joy

# %%
test_df = pd.read_csv("C:\\Users\\akshatha\\Downloads\\archive (5)\\test.txt", sep = ';', names = ['text', 'Emotion'])
print(test_df.head())
# Out:
#                                                 text  Emotion
# 0  im feeling rather rotten so im not very ambiti...  sadness
# 1          im updating my blog because i feel shitty  sadness
# 2  i never make her separate from me because i do...  sadness
# 3  i left with my bouquet of red and yellow tulip...      joy
# 4    i was feeling a little vain when i did this one  sadness

# %%
print(train_df.head())
# Out:
#                                                 text  Emotion
# 0  im feeling rather rotten so im not very ambiti...  sadness
# 1          im updating my blog because i feel shitty  sadness
# 2  i never make her separate from me because i do...  sadness
# 3  i left with my bouquet of red and yellow tulip...      joy
# 4    i was feeling a little vain when i did this one  sadness

# %%
print(train_df.shape)
print(train_df.info())
# Out:
# (2000, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   text     2000 non-null   object
#  1   Emotion  2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB
# None

# %%
print(val_df.shape)
print(val_df.info())
# Out:
# (2000, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   text     2000 non-null   object
#  1   Emotion  2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB
# None

# %%
print(test_df.shape)
print(test_df.info())
# Out:
# (2000, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      2000 non-null   object
#  1   Emotions  2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB
# None

# %%
print(train_df.describe())
print([train_df['Emotion'].value_counts()])
# Out:
#                                                      text Emotion
# count                                                2000    2000
# unique                                               2000       6
# top     im feeling rather rotten so im not very ambiti...     joy
# freq                                                    1     695
# [Emotion
# joy         695
# sadness     581
# anger       275
# fear        224
# love        159
# surprise     66
# Name: count, dtype: int64]

# %%
train_df.isna()
# Out:
#        text  Emotion
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False
# ...     ...      ...
# 1995  False    False
# 1996  False    False
# 1997  False    False
# 1998  False    False
# 1999  False    False
#
# [2000 rows x 2 columns]

# %%
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['clean_text'] = train_df['text'].apply(clean_text)
print(train_df[['text', 'clean_text']].head())
# Out:
#                                                 text  \
# 0  im feeling rather rotten so im not very ambiti...
# 1          im updating my blog because i feel shitty
# 2  i never make her separate from me because i do...
# 3  i left with my bouquet of red and yellow tulip...
# 4    i was feeling a little vain when i did this one
#
#                                           clean_text
# 0  im feeling rather rotten so im not very ambiti...
# 1          im updating my blog because i feel shitty
# 2  i never make her separate from me because i do...
# 3  i left with my bouquet of red and yellow tulip...
# 4    i was feeling a little vain when i did this one

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features = 5000, stop_words = 'english')

X_train = tfidf.fit_transform(train_df['clean_text']).toarray()
Y_train = train_df['Emotion']

print(X_train.shape)
print(tfidf.get_feature_names_out()[:10])
# Out:
# (2000, 4517)
# ['aaaah' 'abandoned' 'abandoning' 'abandonment' 'abba' 'abilities'
#  'ability' 'abit' 'able' 'ablo']

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = model.predict(X_train)
print(classification_report(Y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       1.00      0.89      0.94       275
#         fear       0.97      0.80      0.88       224
#          joy       0.81      1.00      0.89       695
#         love       1.00      0.42      0.59       159
#      sadness       0.91      0.99      0.95       581
#     surprise       1.00      0.12      0.22        66
#
#     accuracy                           0.88      2000
#    macro avg       0.95      0.70      0.74      2000
# weighted avg       0.90      0.88      0.87      2000

# %%
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

val_df['clean_text'] = val_df['text'].apply(clean_text)
print(val_df[['text', 'clean_text']].head())
# Out:
#                                                 text  \
# 0  im feeling quite sad and sorry for myself but ...
# 1  i feel like i am still looking at a blank canv...
# 2                     i feel like a faithful servant
# 3                  i am just feeling cranky and blue
# 4  i can have for a treat or if i am feeling festive
#
#                                           clean_text
# 0  im feeling quite sad and sorry for myself but ...
# 1  i feel like i am still looking at a blank canv...
# 2                     i feel like a faithful servant
# 3                  i am just feeling cranky and blue
# 4  i can have for a treat or if i am feeling festive

# %%
X_val = tfidf.transform(val_df['clean_text']).toarray()
y_val = val_df['Emotion']

val_pred = model.predict(X_val)
print(classification_report(y_val, val_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.91      0.37      0.53       275
#         fear       0.80      0.30      0.44       212
#          joy       0.62      0.94      0.75       704
#         love       0.89      0.09      0.16       178
#      sadness       0.67      0.87      0.76       550
#     surprise       1.00      0.02      0.05        81
#
#     accuracy                           0.66      2000
#    macro avg       0.81      0.43      0.45      2000
# weighted avg       0.73      0.66      0.61      2000

# %%
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

test_df['clean_text'] = test_df['text'].apply(clean_text)
print(test_df[['text', 'clean_text']].head())
# Out:
#                                                 text  \
# 0  im feeling rather rotten so im not very ambiti...
# 1          im updating my blog because i feel shitty
# 2  i never make her separate from me because i do...
# 3  i left with my bouquet of red and yellow tulip...
# 4    i was feeling a little vain when i did this one
#
#                                           clean_text
# 0  im feeling rather rotten so im not very ambiti...
# 1          im updating my blog because i feel shitty
# 2  i never make her separate from me because i do...
# 3  i left with my bouquet of red and yellow tulip...
# 4    i was feeling a little vain when i did this one

# %%
X_test = tfidf.transform(test_df['clean_text']).toarray()
y_test = test_df['Emotion']

test_pred = model.predict(X_test)
print(classification_report(y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       1.00      0.89      0.94       275
#         fear       0.97      0.80      0.88       224
#          joy       0.81      1.00      0.89       695
#         love       1.00      0.42      0.59       159
#      sadness       0.91      0.99      0.95       581
#     surprise       1.00      0.12      0.22        66
#
#     accuracy                           0.88      2000
#    macro avg       0.95      0.70      0.74      2000
# weighted avg       0.90      0.88      0.87      2000

# %%
new_text = ["i remember feeling acutely distressed for a few days"]

new_text_tfidf = tfidf.transform(new_text).toarray()

prediction = model.predict(new_text_tfidf)

print("Predicted Emotion:", prediction[0])
# Out:
# Predicted Emotion: fear
